# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/amazon-reviews/amazon_review_polarity_csv.tgz
# /kaggle/input/amazon-reviews/train.csv
# /kaggle/input/amazon-reviews/test.csv

# %%
df=pd.read_csv('/kaggle/input/amazon-reviews/test.csv')

# %%
df.head()
# Out:
#    2                                           Great CD  \
# 0  2  One of the best game music soundtracks - for a...
# 1  1                   Batteries died within a year ...
# 2  2              works fine, but Maha Energy is better
# 3  2                       Great for the non-audiophile
# 4  1              DVD Player crapped out after one year
#
#   My lovely Pat has one of the GREAT voices of her generation. I have listened to this CD for YEARS and I still LOVE IT. When I'm in a good mood it makes me feel better. A bad mood just evaporates like sugar in the rain. This CD just oozes LIFE. Vocals are jusat STUUNNING and lyrics just kill. One of life's hidden gems. This is a desert isle CD in my book. Why she never made it big is just beyond me. Everytime I play this, no matter black, white, young, old, male, female EVERYBODY says one thing "Who was that singing ?"
# 0  Despite the fact that I have only played a sma...
# 1  I bought this charger in Jul 2003 and it worke...
# 2  Check out Maha Energy's website. Their Powerex...
# 3  Reviewed quite a bit of the combo players and ...
# 4  I also began having the incorrect disc problem...

# %%
df.shape
# Out:
# (399999, 2)

# %% [markdown]
# # 1_for_Negavive
# # 2_for_Positive

# %%
df=df.rename(columns={'2':'sentiment','''My lovely Pat has one of the GREAT voices of her generation. I have listened to this CD for YEARS and I still LOVE IT. When I'm in a good mood it makes me feel better. A bad mood just evaporates like sugar in the rain. This CD just oozes LIFE. Vocals are jusat STUUNNING and lyrics just kill. One of life's hidden gems. This is a desert isle CD in my book. Why she never made it big is just beyond me. Everytime I play this, no matter black, white, young, old, male, female EVERYBODY says one thing "Who was that singing ?"''':'text'})

# %%
df.drop('Great CD',axis=1,inplace=True)

# %%
df.head()
# Out:
#    sentiment                                               text
# 0          2  Despite the fact that I have only played a sma...
# 1          1  I bought this charger in Jul 2003 and it worke...
# 2          2  Check out Maha Energy's website. Their Powerex...
# 3          2  Reviewed quite a bit of the combo players and ...
# 4          1  I also began having the incorrect disc problem...

# %%
df.isnull().sum()
# Out:
# sentiment    0
# text         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(df.text,df.sentiment,test_size= 0.2, random_state=0)

# %%
print(f"X_train = {x_train.shape}")
print(f"Y_train = {y_train.shape}")
print(f"X_test = {x_test.shape}")
print(f"Y_test = {y_test.shape}")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
print(x_train)
# Out:
# 169018    Your standard compilation of quotes from the b...
# 59736     I would love to review this magazine, but unfo...
# 366790    I bought this at the same time that I bought t...
# 105379    I liked this stand very much, and installed it...
# 181239    Amazon has it all wrong! When I ordered the 20...
#                                 ...
# 359783    two mugs in picture, product title states "Mug...
# 358083    Great book for someone interested in photograp...
# 152315    This product sucks. On my Windows XP machine I...
# 117952    I bought this book to refresh my knowledge of ...
# 305711    This is one of those books you read and wich y...
# Name: text, Length: 319999, dtype: object

# %%
feature_extraction=TfidfVectorizer(min_df=1, stop_words ='english', lowercase=True) 
x_train_f= feature_extraction.fit_transform(x_train)
x_test_f= feature_extraction.transform(x_test)

# %%
print(x_train_f)
# Out:
#   (0, 129448)	0.3214701732514318
#   (0, 29590)	0.0638678376844412
#   (0, 151550)	0.17281926816970689
#   (0, 167857)	0.11964176229524648
#   (0, 194230)	0.11613969877632252
#   (0, 62755)	0.1803697800438702
#   (0, 43238)	0.13119326864852787
#   (0, 123938)	0.22041358128211666
#   (0, 23069)	0.1623883709693781
#   (0, 79099)	0.2960141663211733
#   (0, 104332)	0.1685036411755064
#   (0, 27597)	0.20581511126287777
#   (0, 171171)	0.21366497152722386
#   (0, 211159)	0.23571533930160546
#   (0, 129073)	0.17989355855813496
#   (0, 26917)	0.11537003574213064
#   (0, 133485)	0.28081414548755795
#   (0, 46221)	0.16194355374334504
#   (0, 119796)	0.3214701732514318
#   (0, 17538)	0.23725065015883118
#   (0, 69265)	0.124593176725785
#   (0, 30736)	0.1650296911179204
#   (0, 156319)	0.19926665322556672
#   (0, 44532)	0.1808274982558626
#   (0, 183010)	0.15833603159019935
#   :	:
#   (319998, 114244)	0.1493951198347953
#   (319998, 30317)	0.12236938396421192
#   (319998, 200640)	0.2115855840509042
#   (319998, 85512)	0.1256446235227951
#   (319998, 176044)	0.11619883927365965
#   (319998, 19199)	0.12361362379540929
#   (319998, 215100)	0.10309743755120596
#   (319998, 38723)	0.09792525051817656
#   (319998, 36657)	0.10078860092997234
#   (319998, 194278)	0.10465408631506262
#   (319998, 108801)	0.12549498027423547
#   (319998, 158115)	0.1309664395415406
#   (319998, 118961)	0.10747545133135802
#   (319998, 129132)	0.14404589538233045
#   (319998, 48519)	0.10513834315911279
#   (319998, 29752)	0.07884404575811654
#   (319998, 158019)	0.1862359287519977
#   (319998, 163557)	0.08890616296741083
#   (319998, 20760)	0.1732660384952509
#   (319998, 209954)	0.09467798131148981
#   (319998, 114447)	0.0520504632927235
#   (319998, 22310)	0.15886209612408564
#   (319998, 215464)	0.09735206899018914
#   (319998, 57203)	0.07088456639333472
#   (319998, 29590)	0.09844923729421984

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(max_iter=1000)
lr
# Out:
# LogisticRegression(max_iter=1000)

# %%
print(x_test_f.dtype)
# Out:
# float64

# %%
print(x_train_f[100])
# Out:
#   (0, 152989)	0.20859054469245233
#   (0, 80871)	0.1649214734495265
#   (0, 183868)	0.35681755238571344
#   (0, 209699)	0.18518821682341527
#   (0, 114850)	0.25271471056454897
#   (0, 98343)	0.2031244190783108
#   (0, 142555)	0.20503324972187165
#   (0, 210564)	0.3228587937853926
#   (0, 47694)	0.21298097393520093
#   (0, 15599)	0.20859054469245233
#   (0, 174865)	0.18219317236770632
#   (0, 102637)	0.18413112289684208
#   (0, 119173)	0.1412429157214631
#   (0, 115555)	0.12289333581771321
#   (0, 58132)	0.37885610317437407
#   (0, 105556)	0.13911504957871304
#   (0, 194210)	0.11455720736359978
#   (0, 117229)	0.1776109352437297
#   (0, 213664)	0.1379464090423929
#   (0, 24082)	0.15892201021695707
#   (0, 40276)	0.18791778003958093
#   (0, 26295)	0.10300020244867153
#   (0, 109546)	0.10531653369830206
#   (0, 214684)	0.10161302771589004
#   (0, 85051)	0.07795269913477941

# %%
lr.fit(x_train_f,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
print(x_test_f)
# Out:
#   (0, 215377)	0.12063078488289342
#   (0, 214847)	0.09599101745766138
#   (0, 214622)	0.11723369557170273
#   (0, 195543)	0.06227222760786648
#   (0, 194698)	0.08415268568047822
#   (0, 194278)	0.10932802530335363
#   (0, 191719)	0.1291241624765361
#   (0, 185266)	0.14507435490402648
#   (0, 184122)	0.16088042832028107
#   (0, 175434)	0.1376899369531353
#   (0, 159430)	0.17570397412878466
#   (0, 147473)	0.10244736055846854
#   (0, 142809)	0.13000445047887862
#   (0, 141437)	0.10939263416551105
#   (0, 136483)	0.21218221501373125
#   (0, 132412)	0.12948226972578386
#   (0, 116801)	0.07187278018761147
#   (0, 114447)	0.05437508049887893
#   (0, 111533)	0.19457207871254645
#   (0, 96904)	0.18517145521555095
#   (0, 95607)	0.25054183456155626
#   (0, 94445)	0.10402213825235206
#   (0, 94355)	0.13634153435401278
#   (0, 94245)	0.16955542013835778
#   (0, 94025)	0.22039744708899012
#   :	:
#   (79998, 114447)	0.05558665516205591
#   (79998, 108801)	0.13402082809218988
#   (79998, 102726)	0.2132468424347281
#   (79998, 95071)	0.21641723023741194
#   (79998, 95016)	0.11415239872377458
#   (79998, 81173)	0.27579955391268535
#   (79998, 77676)	0.14252856848923406
#   (79998, 73726)	0.17075825653540405
#   (79998, 48420)	0.17353931899762573
#   (79998, 41692)	0.19957540657487863
#   (79998, 33829)	0.14610671396500108
#   (79998, 3052)	0.13750175213035926
#   (79999, 198601)	0.2314256302773337
#   (79999, 190119)	0.2284885103313012
#   (79999, 185480)	0.4770263999813062
#   (79999, 151724)	0.17015975138512024
#   (79999, 129132)	0.2722980877567428
#   (79999, 129073)	0.2620954394934007
#   (79999, 113570)	0.18023410416773492
#   (79999, 111660)	0.46836510999989633
#   (79999, 86359)	0.10507986591025643
#   (79999, 85051)	0.10343524894157055
#   (79999, 43726)	0.2400695883186619
#   (79999, 42533)	0.3501923394549817
#   (79999, 39800)	0.20255237264817488

# %%
y_hat=lr.predict(x_test_f)

# %%
from sklearn.metrics import accuracy_score

# %%
print(f"Accuracy Score : {accuracy_score(y_test,y_hat)}")
# Out:
# Accuracy Score : 0.86785

# %%
# from sklearn.model_selection import GridSearchCV

# %%
# param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
# grid= GridSearchCV(LogisticRegression(max_iter=1000), param_grid)
# grid.fit(x_train_f,y_train)

# %%
# print("Best parameters :", grid.best_params_)

# %% [markdown]
# # 1_for_Negavive
# # 2_for_Positive

# %% [markdown]
# can test with custom i/p

# %%
ip=['''I recently purchased the XYZ Wireless Headphones, and I have been incredibly impressed with their performance. The sound quality is top-notch, with deep bass and clear highs that make my music sound fantastic. The Bluetooth connectivity is seamless and has a great range, allowing me to move around my home without losing connection.The comfort level of these headphones is outstanding. They fit snugly over my ears without feeling too tight, and the padded ear cushions make them suitable for long listening sessions. Plus, the foldable design makes them easy to carry in my bag when I'm on the go.
Battery life is another standout feature. I can use them for several days on a single charge, which is fantastic for my daily commute and workouts.Overall, I highly recommend the XYZ Wireless Headphones to anyone in need of a reliable and high-quality audio experience. They exceeded my expectations, and I couldn't be happier with my purchase!''']
feat= feature_extraction.transform(ip)
pred = lr.predict(feat)
print(pred)
# Out:
# [2]
